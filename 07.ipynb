# %%
idade = int(input("Digite sua idade: "))

if idade <= 12:
    print("\n=====| Criança |=====")
    
elif idade <= 17:
    print("\n=====| Adolescente |=====")

else:
    print("\n=====| Adulto |=====")
