# %%
a = "Eu estou aprendendo python"
print(a)
# Out:
# Eu estou aprendendo python

# %%
b = "Meu nome é Gustavo"
c = "Eu moro em Goiania"
print(b)
print(c)
# Out:
# Meu nome é Gustavo
# Eu moro em Goiania

# %%
nome = ("Gustavo")
idade = 17
print("Meu nome é",nome,"e eu tenho",idade,"anos")
# Out:
# Meu nome é Gustavo e eu tenho 17 anos

# %%
cidade = ("Ap. Goiania")
estado = ("Go")
pais = ("Brasil")
print("Eu moro na cidade de",cidade,",",estado,"no",pais,)
# Out:
# Eu moro na cidade de Ap. Goiania , Go no Brasil
