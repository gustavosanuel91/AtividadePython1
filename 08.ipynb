# %%
nota = int(input("Digite sua nota: "))

if nota >= 7:
    print("\n=====| Aprovado! |=====")

elif nota >= 5:
    print("\n=====| Recuperação! |=====")

else:
    print("\n=====| Reprovado! |=====")
